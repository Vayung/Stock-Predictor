# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install yfinance

import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in c:\users\taiwo\anaconda3\lib\site-packages (1.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\taiwo\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\taiwo\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\taiwo\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\taiwo\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: pycparser in c:\users\taiwo\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taiwo\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\taiwo\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\taiwo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\taiwo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\taiwo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\taiwo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)

# %%
start = '2015-01-01'
end = '2025-12-20'
stock = 'NVDA'

data = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   NVDA        NVDA        NVDA        NVDA       NVDA
# 0      2015-01-02    0.483011    0.486611    0.475333    0.483011  113680000
# 1      2015-01-05    0.474853    0.484451    0.472694    0.483011  197952000
# 2      2015-01-06    0.460456    0.476053    0.459977    0.475573  197764000
# 3      2015-01-07    0.459257    0.467895    0.457817    0.463816  321808000
# 4      2015-01-08    0.476533    0.479412    0.464296    0.464536  283780000
# ...           ...         ...         ...         ...         ...        ...
# 2754   2025-12-15  176.289993  178.419998  175.029999  177.940002  164775600
# 2755   2025-12-16  177.720001  178.490005  174.899994  176.259995  148588100
# 2756   2025-12-17  170.940002  176.130005  170.309998  176.100006  222775500
# 2757   2025-12-18  174.139999  176.149994  171.820007  174.529999  176096000
# 2758   2025-12-19  180.990005  181.449997  176.339996  176.669998  324925900
#
# [2759 rows x 6 columns]

# %%
ma_100_days=data.Close.rolling(100).mean()

# %%
plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r')
plt.plot(data.Close, 'g')
plt.show()

# %%
ma_200_days = data.Close.rolling(200).mean()

# %%
plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r')
plt.plot(ma_200_days, 'b')
plt.plot(data.Close, 'g')
plt.show()

# %%
data.dropna(inplace=True)

# %%
data_train = pd.DataFrame(data.Close[0: int(len(data)*0.80)])
# Create a new column named 'test' using bracket notation
data['test'] = pd.DataFrame(data.Close[int(len(data) * 0.8): len(data)])

# %%
data_train.shape[0]
# Out:
# 2207

# %%
 data['test'].shape[0]
# Out:
# 2759

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_train_scale= scaler.fit_transform(data_train)

# %%
x = []
y = []
for i in range(100, data_train_scale.shape[0]):
    x.append(data_train_scale[i-100:i])
    y.append(data_train_scale[i,0])

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\taiwo\anaconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\taiwo\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\taiwo\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\taiwo\anaconda3\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\taiwo\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\taiwo\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\taiwo\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# INFO: pip is looking at multiple versions of tensorflow to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement grpcio<2.0,>=1.24.3 (from tensorflow) (from versions: none)
# ERROR: No matching distribution found for grpcio<2.0,>=1.24.3

# %%
# !pip install --upgrade pip
# !pip install --upgrade setuptools
# Out:
# Requirement already satisfied: pip in c:\users\taiwo\anaconda3\lib\site-packages (25.1)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.0 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# C:\Users\Taiwo\anaconda3\python.exe -m pip install --upgrade pip
# Requirement already satisfied: setuptools in c:\users\taiwo\anaconda3\lib\site-packages (72.1.0)
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 72.1.0
#     Uninstalling setuptools-72.1.0:
#       Successfully uninstalled setuptools-72.1.0
# Successfully installed setuptools-80.9.0

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\taiwo\anaconda3\lib\site-packages (25.1)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1
#     Uninstalling pip-25.1:
#       Successfully uninstalled pip-25.1
# Successfully installed pip-25.3

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential
